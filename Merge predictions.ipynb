# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
pd.set_option('display.max_columns', 500)

import datetime

from __future__ import division

import seaborn as sns

from sklearn import linear_model

# %%
DT_pred = pd.read_csv('predictions/DT_prediction_422.csv')

# %%
LR_pred = pd.read_csv('predictions/LR_prediction_422.csv')

# %%
DT_pred.head()
# Out:
#    tollgate_id                                time_window  direction  volume
# 0            1  [2016-10-18 08:00:00,2016-10-18 08:20:00)          0      43
# 1            1  [2016-10-19 08:00:00,2016-10-19 08:20:00)          0      44
# 2            1  [2016-10-20 08:00:00,2016-10-20 08:20:00)          0      43
# 3            1  [2016-10-21 08:00:00,2016-10-21 08:20:00)          0      37
# 4            1  [2016-10-22 08:00:00,2016-10-22 08:20:00)          0      43

# %%
DT_LR_pred = DT_pred.copy()
DT_LR_pred['volume'] = np.array([0] * len(DT_LR_pred))

# %%
lr_pred = LR_pred.sort(columns='time_window')['volume'].tolist()
dt_pred = DT_pred.sort(columns='time_window')['volume'].tolist()
# Out:
# C:\Users\THINKPAD\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# C:\Users\THINKPAD\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
print np.corrcoef(lr_pred, dt_pred)
# Out:
# [[ 1.          0.87890595]
#  [ 0.87890595  1.        ]]

# %%
print lr_pred[:10]
print dt_pred[:10]
print ((np.array(lr_pred) + np.array(dt_pred)) / 2)[:10]
# Out:
# [31L, 79L, 121L, 87L, 95L, 31L, 95L, 79L, 128L, 87L]
# [43L, 108L, 144L, 118L, 112L, 43L, 112L, 108L, 144L, 118L]
# [  37.    93.5  132.5  102.5  103.5   37.   103.5   93.5  136.   102.5]

# %%
DT_LR_pred['volume'] = (np.array(lr_pred) + np.array(dt_pred)) / 2

# %%
DT_LR_pred.to_csv("predictions/DT_LR_pred_422.csv", index=False)

# %%
DT_LR_pred = pd.read_csv("predictions/DT_LR_pred_422.csv")

# %%
DT_LR_pred
# Out:
#      tollgate_id                                time_window  direction  volume
# 0              1  [2016-10-18 08:00:00,2016-10-18 08:20:00)          0    37.0
# 1              1  [2016-10-19 08:00:00,2016-10-19 08:20:00)          0    93.5
# 2              1  [2016-10-20 08:00:00,2016-10-20 08:20:00)          0   132.5
# 3              1  [2016-10-21 08:00:00,2016-10-21 08:20:00)          0   102.5
# 4              1  [2016-10-22 08:00:00,2016-10-22 08:20:00)          0   103.5
# 5              1  [2016-10-23 08:00:00,2016-10-23 08:20:00)          0    37.0
# 6              1  [2016-10-24 08:00:00,2016-10-24 08:20:00)          0   103.5
# 7              1  [2016-10-18 08:20:00,2016-10-18 08:40:00)          0    93.5
# 8              1  [2016-10-19 08:20:00,2016-10-19 08:40:00)          0   136.0
# 9              1  [2016-10-20 08:20:00,2016-10-20 08:40:00)          0   102.5
# 10             1  [2016-10-21 08:20:00,2016-10-21 08:40:00)          0   140.0
# ...
